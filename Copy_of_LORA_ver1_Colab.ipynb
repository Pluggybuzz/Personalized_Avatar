# %% [markdown]
# <a href="https://colab.research.google.com/github/Pluggybuzz/Personalized_Avatar/blob/main/Copy_of_LORA_ver1_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A notebook for finetuning Stable Diffusion using LORA.
#
# Tested with [Stable Diffusion v1-5](https://huggingface.co/runwayml/stable-diffusion-v1-5).
#
# Notebook developed by [pedrogengo](https://github.com/pedrogengo).

# %% [markdown]
# # SETUP

# %%
# !git clone https://github.com/cloneofsimo/lora.git && sed -i 's/functools.cache/functools.lru_cache(maxsize=None)/g' /content/lora/lora_diffusion/xformers_utils.py && pip install /content/lora
# !pip install accelerate bitsandbytes
# Out:
# Cloning into 'lora'...
# remote: Enumerating objects: 937, done.
# remote: Counting objects: 100% (437/437), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 937 (delta 371), reused 307 (delta 307), pack-reused 500 (from 1)
# Receiving objects: 100% (937/937), 182.96 MiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (559/559), done.
# Updating files: 100% (61/61), done.
# Processing ./lora
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 36.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # TRAINING

# %%
import os
import shutil
from google.colab import files
from tqdm import tqdm

PRETRAINED_MODEL="runwayml/stable-diffusion-v1-5" #@param{type: 'string'}
PROMPT="ktn" #@param{type: 'string'}

OUTPUT_DIR="" #@param{type: 'string'}
IMAGES_FOLDER_OPTIONAL="" #@param{type: 'string'}

RESOLUTION="512" #@param ["512", "576", "640", "704", "768", "832", "896", "960", "1024"]
RESOLUTION=int(RESOLUTION)

if PRETRAINED_MODEL == "":
  print('[1;31mYou should define the pretrained model.')

else:
  if IMAGES_FOLDER_OPTIONAL=="":
    INSTANCE_DIR = "/content/data_example"
    if not os.path.exists(str(INSTANCE_DIR)):
      # %mkdir -p "$INSTANCE_DIR"
    uploaded = files.upload()
    for filename in tqdm(uploaded.keys(), bar_format='  |{bar:15}| {n_fmt}/{total_fmt} Uploaded'):
        shutil.move(filename, INSTANCE_DIR)
  else:
    INSTANCE_DIR = IMAGES_FOLDER_OPTIONAL

  if OUTPUT_DIR == "":
    OUTPUT_DIR = "/content/output"
  if not os.path.exists(str(OUTPUT_DIR)):
    # %mkdir -p "$OUTPUT_DIR"
# Out:
#      <input type="file" id="files-72ac498d-3282-4937-bf5d-8e2a69cb247f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72ac498d-3282-4937-bf5d-8e2a69cb247f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip uninstall -y diffusers
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# Found existing installation: diffusers 0.33.1
# Uninstalling diffusers-0.33.1:
#   Successfully uninstalled diffusers-0.33.1
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-il0iigmj
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-il0iigmj
#   Resolved https://github.com/huggingface/diffusers to commit 0c47c954f38f7fa77bad54424046973a7d08c771
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.34.0.dev0-py3-none-any.whl size=3659251 sha256=4cf5f51f9d5494f2a19c2d853e079e6af131f997fcb7c6096ad2280ae653e71a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4e3p5yfe/wheels/90/fb/48/a310c271ab42899362ff272062ced42133e5c4c9d0ce77df68
# Successfully built diffusers
# ...

# %%
# !git clone https://github.com/huggingface/diffusers
# %cd diffusers/examples/dreambooth
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 91144, done.
# remote: Counting objects: 100% (791/791), done.
# remote: Compressing objects: 100% (395/395), done.
# remote: Total 91144 (delta 661), reused 396 (delta 396), pack-reused 90353 (from 5)
# Receiving objects: 100% (91144/91144), 67.84 MiB | 14.16 MiB/s, done.
# Resolving deltas: 100% (66896/66896), done.
# /content/diffusers/examples/dreambooth

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora.py -O /content/diffusers/examples/dreambooth/train_dreambooth_lora.py
# Out:
# --2025-05-09 09:13:49--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59166 (58K) [text/plain]
# Saving to: ‘/content/diffusers/examples/dreambooth/train_dreambooth_lora.py’
#
# /content/diffusers/ 100%[===================>]  57.78K  --.-KB/s    in 0.001s
#
# 2025-05-09 09:13:49 (67.9 MB/s) - ‘/content/diffusers/examples/dreambooth/train_dreambooth_lora.py’ saved [59166/59166]

# %%
# !pip install bitsandbytes

# %%
# --- Configuration ---
STEPS = 1040
BATCH_SIZE = 6
FP_16 = True
PRETRAINED_MODEL = "runwayml/stable-diffusion-v1-5"
INSTANCE_DIR = "/content/data_example"
OUTPUT_DIR = "/content/output"
PROMPT = "ktn"
LEARNING_RATE = 1e-4
TRAIN_TEXT_ENCODER = True
LEARNING_RATE_TEXT_ENCODER = 5e-5

# Derived config
NEW_LEARNING_RATE = LEARNING_RATE / BATCH_SIZE
NEW_LEARNING_RATE_TEXT_ENCODER = LEARNING_RATE_TEXT_ENCODER / BATCH_SIZE
fp_16_arg = "fp16" if FP_16 else "no"

# Clean up old checkpoints
# !rm -rf {INSTANCE_DIR}/.ipynb_checkpoints

# --- Training command ---
base_cmd = (
    f"accelerate launch /content/diffusers/examples/dreambooth/train_dreambooth_lora.py "
    f"--pretrained_model_name_or_path=\"{PRETRAINED_MODEL}\" "
    f"--instance_data_dir=\"{INSTANCE_DIR}\" "
    f"--output_dir=\"{OUTPUT_DIR}\" "
    f"--instance_prompt=\"{PROMPT}\" "
    f"--resolution=512 "
    f"--use_8bit_adam "
    f"--mixed_precision=\"{fp_16_arg}\" "
    f"--train_batch_size=1 "
    f"--gradient_accumulation_steps=1 "
    f"--learning_rate={NEW_LEARNING_RATE} "
    f"--lr_scheduler=\"constant\" "
    f"--lr_warmup_steps=0 "
    f"--max_train_steps={STEPS} "
    f"--lora_rank=16 "
    f"--learning_rate_text={NEW_LEARNING_RATE_TEXT_ENCODER} "
)

if TRAIN_TEXT_ENCODER:
    base_cmd += "--train_text_encoder "

# Run training
# !{base_cmd}
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-05-09 09:19:43.407352: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746782383.429422    4604 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !pip install --upgrade --force-reinstall numpy
# Out:
# ...
#   Using cached numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.2.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.5 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.5 which is incompatible.
# ...

# %%
# !pip install --upgrade --force-reinstall torch torchvision
# Out:
# ...
#   Using cached torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ...
#   Using cached torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !pip install --upgrade --force-reinstall transformers diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 102.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.3/484.3 kB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 81.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.7 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade --no-cache-dir numpy

# %%
pip install --upgrade diffusers

# %%
pip install peft safetensors

# %%
    # !pip install safetensors torch

# %%
pip install bitsandbytes

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # INFERENCE

# %%
# !pip install diffusers --upgrade

# %%
pip install safetensors

# %%
import os
from safetensors.torch import load_file, save_file
from diffusers import StableDiffusionPipeline
import torch

# Step 1: Split pytorch_lora_weights.safetensors
lora_weights_path = "/content/output/pytorch_lora_weights.safetensors"
output_dir = "/content/output"
unet_weights_path = os.path.join(output_dir, "lora_weights.safetensors")
text_encoder_weights_path = os.path.join(output_dir, "lora_weights.text_encoder.safetensors")

if not os.path.exists(lora_weights_path):
    raise FileNotFoundError(f"LoRA weights file not found at {lora_weights_path}")

os.makedirs(output_dir, exist_ok=True)
weights = load_file(lora_weights_path)


# Filter weights for UNet and Text Encoder
unet_weights = {k: v for k, v in weights.items() if any(term in k.lower() for term in ["unet", "down_blocks", "up_blocks", "mid_block", "attn1", "attn2", "cross_attention", "attention"])}
text_encoder_weights = {k: v for k, v in weights.items() if any(term in k.lower() for term in ["text_encoder", "clip", "transformer", "self_attn"])}

# Save weights if they exist
if unet_weights:
    save_file(unet_weights, unet_weights_path)
    print(f"Saved UNet weights to {unet_weights_path}")
else:
    print("No UNet weights found")

if text_encoder_weights:
    save_file(text_encoder_weights, text_encoder_weights_path)
    print(f"Saved Text Encoder weights to {text_encoder_weights_path}")
else:
    print("No Text Encoder weights found")

# Step 2: Load pipeline and apply LoRA weights
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16
).to("cuda")

# Apply LoRA weights using diffusers' native support
if os.path.exists(unet_weights_path):
    pipe.load_lora_weights(output_dir, weight_name="lora_weights.safetensors")
    print("UNet LoRA weights applied successfully")
else:
    print("Skipping UNet LoRA weights application (file not found)")

if os.path.exists(text_encoder_weights_path):
    pipe.load_lora_weights(output_dir, weight_name="lora_weights.text_encoder.safetensors")
    print("Text Encoder LoRA weights applied successfully")
else:
    print("Skipping Text Encoder LoRA weights application (file not found)")

# Step 3: Inference with user-specified prompt
# Replace this prompt with one that matches your trained images
INFERENCE_PROMPT = "a photo of ktn make this into his wearing the space suit and working in space without helmet "
GUIDANCE = 7.5  # Typical value for good prompt adherence

try:
    image = pipe(INFERENCE_PROMPT, num_inference_steps=50, guidance_scale=GUIDANCE).images[0]
    image.save("/content/output/generated_image.png")
    print("Image generated and saved to /content/output/generated_image.png")
    image  # Displays in notebook
except Exception as e:
    print(f"Inference failed: {e}")
# Out:
# Saved UNet weights to /content/output/lora_weights.safetensors
# Saved Text Encoder weights to /content/output/lora_weights.text_encoder.safetensors
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# UNet LoRA weights applied successfully
# Text Encoder LoRA weights applied successfully
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image generated and saved to /content/output/generated_image.png
